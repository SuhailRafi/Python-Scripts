# %%
# This script is for scrapping files from Google Drive
# Feel free to customize and use it in any other environments or configuration

from google.colab import drive 
drive.mount ('/content/drive') 

with open("The .csv Path Goes Here", 'r') as file: 
    inp = file.readlines() 

x="" 
y=x.join (inp) 
x=y.replace ("\t", ",") 

with open("The .csv Path Goes Here", 'w') as file: 
    inp= file.write (x)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
inp
# Out:
# 6204
