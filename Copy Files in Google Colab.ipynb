# %%
cd drive
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
pwd
# Out:
# '/content/drive/My Drive/MT'

# %%
cd 'ROS for Beginners Basics, Motion, and OpenCV'
# Out:
# /content/drive/.shortcut-targets-by-id/193/ROS for Beginners Basics, Motion, and OpenCV

# %%
# !cp -r '/content/drive/.shortcut-targets-by-id/193/ROS for Beginners Basics, Motion, and OpenCV' '/content/drive/My Drive'
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
